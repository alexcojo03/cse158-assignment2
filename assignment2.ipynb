# %% [markdown]
# # Assignment 2
# ## Twitch Recommendation System
# Authors: Alex Cojocaru, Kyle Jorrin, Diego Otero-Caldwell, Drumm

# %% [markdown]
# Research articles to get started:\
# [YouTube Recommendation Algorithm](https://dl.acm.org/doi/abs/10.1145/1864708.1864770)\
# [Overview Of Recommender Systems](https://search-library.ucsd.edu/permalink/01UCS_SDI/1vtf07t/cdi_doaj_primary_oai_doaj_org_article_e1fff15ae9b64b96915b66bc5dc81ac5)\
# ...

# %%
# If first time, run this script to set up virtual environment
# Requires python3.11
# !chmod +x scripts/setup_env.sh
# !./scripts/setup_env.sh
# Out:
# Requirement already satisfied: pip in ./.venv/lib/python3.11/site-packages (25.3)
# Obtaining file:///Users/alexcojocaru/School/UCSD/FA2025/CSE158/cse158-assignment2
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in ./.venv/lib/python3.11/site-packages (from cse158-assignment2==0.1.0) (2.32.5)
# Requirement already satisfied: python-magic in ./.venv/lib/python3.11/site-packages (from cse158-assignment2==0.1.0) (0.4.27)
# Requirement already satisfied: implicit in ./.venv/lib/python3.11/site-packages (from cse158-assignment2==0.1.0) (0.7.2)
# Collecting pandas (from cse158-assignment2==0.1.0)
#   Downloading pandas-2.3.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (91 kB)
# Requirement already satisfied: numpy>=1.17.0 in ./.venv/lib/python3.11/site-packages (from implicit->cse158-assignment2==0.1.0) (2.3.5)
# Requirement already satisfied: scipy>=0.16 in ./.venv/lib/python3.11/site-packages (from implicit->cse158-assignment2==0.1.0) (1.16.3)
# Requirement already satisfied: tqdm>=4.27 in ./.venv/lib/python3.11/site-packages (from implicit->cse158-assignment2==0.1.0) (4.67.1)
# Requirement already satisfied: threadpoolctl in ./.venv/lib/python3.11/site-packages (from implicit->cse158-assignment2==0.1.0) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.11/site-packages (from pandas->cse158-assignment2==0.1.0) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->cse158-assignment2==0.1.0)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->cse158-assignment2==0.1.0)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->cse158-assignment2==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests->cse158-assignment2==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.11/site-packages (from requests->cse158-assignment2==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.11/site-packages (from requests->cse158-assignment2==0.1.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.11/site-packages (from requests->cse158-assignment2==0.1.0) (2025.11.12)
# Downloading pandas-2.3.3-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 591.1 kB/s  0:00:18 eta 0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Building wheels for collected packages: cse158-assignment2
#   Building editable for cse158-assignment2 (pyproject.toml) ... done
#   Created wheel for cse158-assignment2: filename=cse158_assignment2-0.1.0-0.editable-py3-none-any.whl size=2909 sha256=9f05bebbdca17f4c464e62937d2d695b04ac4aaf528d17e50b4de236a5efd2df
#   Stored in directory: /private/var/folders/f4/qprx1wk556z1vmxyvk0vzgyh0000gn/T/pip-ephem-wheel-cache-izg4383s/wheels/bc/96/4a/aa3fbc2fff167d5b4723154e8e27e88a76c7b7ee1a5d45f127
# Successfully built cse158-assignment2
# Installing collected packages: pytz, tzdata, pandas, cse158-assignment2
#   Attempting uninstall: cse158-assignment2━━━━━━━━━━━━━━━━━━━ 2/4 [pandas]
#     Found existing installation: cse158-assignment2 0.1.0━━━━━ 2/4 [pandas]
#     Uninstalling cse158-assignment2-0.1.0:m━━━━━━━━━━━━━━━━━━━ 2/4 [pandas]
#       Successfully uninstalled cse158-assignment2-0.1.0━━━━━━━ 2/4 [pandas]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [cse158-assignment2]s]
# Successfully installed cse158-assignment2-0.1.0 pandas-2.3.3 pytz-2025.2 tzdata-2025.2
#
# Environment created. Run 'source .venv/bin/activate' to activate it.

# %% [markdown]
# Data link: https://cseweb.ucsd.edu/~jmcauley/datasets.html#twitch
#
# Start and stop times are provided as integers and represent periods of 10 minutes. Stream ID could be used to retrieve a single broadcast segment from a streamer (not used in our work).
#
#     User ID (anonymized)
#     Stream ID
#     Streamer username
#     Time start
#     Time stop
#
# [Original research paper of the data](https://search-library.ucsd.edu/permalink/01UCS_SDI/1vtf07t/cdi_unpaywall_primary_10_1145_3460231_3474267)

# %% [markdown]
# Load in the data

# %%
# Imports
import pandas as pd
import numpy as np

# %%
# Data with header names
data = pd.read_csv('100k_a.csv', names=['user_id', 'stream_id', 'streamer_username', 'time_start', 'time_stop'])
data.head()
# Out:
#    user_id    stream_id streamer_username  time_start  time_stop
# 0        1  33842865744          mithrain         154        156
# 1        1  33846768288             alptv         166        169
# 2        1  33886469056          mithrain         587        588
# 3        1  33887624992              wtcn         589        591
# 4        1  33890145056         jrokezftw         591        594

# %% [markdown]
# ### Training the model (Part 3)
# #### From section 4.2 of the paper

# %%
# Replace surprise with implicit
import implicit
from scipy.sparse import csr_matrix

# Prepare sparse matrix
user_item = csr_matrix((data['rating'], (data['user_id'], data['stream_id'])))

# Train ALS model
model = implicit.als.AlternatingLeastSquares(factors=50)
model.fit(user_item)

# Recommend for user 0
recommendations = model.recommend(0, user_item[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/School/UCSD/FA2025/CSE158/cse158-assignment2/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 6
#       3 from scipy.sparse import csr_matrix
#       5 # Prepare sparse matrix
# ----> 6 user_item = csr_matrix((data['rating'], (data['user_id'], data['stream_id'])))
#       8 # Train ALS model
#       9 model = implicit.als.AlternatingLeastSquares(factors=50)
#
# File ~/School/UCSD/FA2025/CSE158/cse158-assignment2/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~/School/UCSD/FA2025/CSE158/cse158-assignment2/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'rating'
